# %% [markdown]
# <a href="https://colab.research.google.com/github/OWEN-JUN/keras_/blob/master/day0731_keras31_sklearn_model_selection_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from keras.datasets import boston_housing
from keras.models import Sequential
from keras.layers import Dense, LSTM, Dropout, BatchNormalization

import numpy as np
from sklearn.model_selection import KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
(x_train, y_train),(x_test, y_test) = boston_housing.load_data()

print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(x_train[0])
# stand = StandardScaler()
norm = MinMaxScaler()
# stand.fit(x_train)
# x_train = stand.transform(x_train)
# x_test = stand.transform(x_test)
norm.fit(x_train)
x_train = norm.transform(x_train)
x_test = norm.transform(x_test)

# mean = x_train.mean(axis=0)
# x_train -= mean
# std = x_train.std(axis=0)
# x_train /= std

# x_test -= mean
# x_test /= std
# print(type(x_train))
# print(x_train[0:3])
from keras.layers import *
from keras.models import *

def build_model():
  model = Sequential()
  model.add(Dense(300, activation="relu", input_shape=(x_train.shape[1],)))
  model.add(Dense(500, activation="relu"))

  model.add(Dense(50, activation="relu"))
  model.add(Dense(1))
  model.compile(optimizer="rmsprop", loss="mse", metrics=["mae"])
  return model


k=4
num_val_samples = len(x_train)//k
num_epochs = 100
all_scores = []
# skf = KFold(n_splits=K)
# for train_index, test_index in skf.split(x_train,y_train):
#     print("TRAIN:", train_index, "TEST:", test_index)
#     x, x_train_test = x_train[train_index], x_train[test_index]
#     y, y_train_test = y_train[train_index], y_train[test_index]

# print(len(x),len(x_train_test))



from sklearn.model_selection import StratifiedKFold
seed = 77
from keras.wrappers.scikit_learn import KerasClassifier, KerasRegressor
from sklearn.model_selection import KFold, cross_val_score
model = KerasRegressor(build_fn = build_model, epochs = 10, batch_size=1, verbose=1)
kfold = KFold(n_splits=5, shuffle = True, random_state=seed)
results = cross_val_score(model, x_train, y_train, cv=kfold,error_score="mae")

print(results)
print(np.mean(results))
# Out:
# (404, 13)
# (102, 13)
# (404,)
# [  1.23247   0.        8.14      0.        0.538     6.142    91.7
#    3.9769    4.      307.       21.      396.9      18.72   ]
# Epoch 1/10
# 323/323 [==============================] - 1s 4ms/step - loss: 70.2817 - mean_absolute_error: 5.7989
# Epoch 2/10
# 323/323 [==============================] - 1s 3ms/step - loss: 32.8765 - mean_absolute_error: 3.9026
# Epoch 3/10
# 323/323 [==============================] - 1s 3ms/step - loss: 26.2086 - mean_absolute_error: 3.4489
# Epoch 4/10
# 323/323 [==============================] - 1s 3ms/step - loss: 23.6180 - mean_absolute_error: 3.1924
# Epoch 5/10
# 323/323 [==============================] - 1s 3ms/step - loss: 21.0334 - mean_absolute_error: 3.0011
# Epoch 6/10
# 323/323 [==============================] - 1s 3ms/step - loss: 19.6820 - mean_absolute_error: 3.0486
# Epoch 7/10
# 323/323 [==============================] - 1s 3ms/step - loss: 19.7874 - mean_absolute_error: 2.8607
# Epoch 8/10
# ...

# %%
for i in results:
    
print(np.mean(results))
# Out:
# [-16.02334153 -11.59687177 -19.65262502 -12.25562337 -19.03048882]
# -15.71179010160886
